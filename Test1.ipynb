# %% [markdown]
# <a href="https://colab.research.google.com/github/mramesh907/Google-Colab/blob/main/Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

dict={
    "name" : ['r','a','m'],
    "marks" : [92,90,70],
    "city" : ['rampur','us','uk']
}
df=pd.DataFrame(dict)
df
# Out:
#   name  marks    city
# 0    r     92  rampur
# 1    a     90      us
# 2    m     70      uk

# %% [markdown]
# Data read from csv and excel

# %%
data1=pd.read_csv("/content/industry.csv")
print(data1)
data2=pd.read_excel("/content/Deep Learning.xlsx")
print(data2)

# %% [markdown]
# Exploring Data

# %%
data=pd.read_excel("/content/file_example_XLS_100.xls")
# print(data)
# print(data.head(10)) #head values
# print(data.tail(30))
# print(data.info())
# print(data.describe())
print(data.isnull().sum())
# Out:
# 0             0
# First Name    0
# Last Name     0
# Gender        0
# Country       0
# Age           0
# Date          0
# Id            0
# dtype: int64

# %% [markdown]
# Handling Duplicates

# %%
data=pd.read_excel("/content/file_example_XLS_10.xls")
# print(data)
# print(data.duplicated())
# print(data["Age"].duplicated().sum())
print(data.drop_duplicates("Age"))
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %% [markdown]
# Working with Missing Data

# %%
data=pd.read_excel("/content/file_example_XLS_10.xls")
# print(data)
# print(data.isnull().sum())
# print(data.dropna())
import numpy as np
# print(data.replace(np.nan,2563))
# print(data["Age"].mean()) #34
# data["Age"]=data["Age"].replace(np.nan,34)
print(data)
print("------------------------------------")
print(data.fillna(method="bfill"))
print("------------------------------------")
print(data.fillna("Nothing"))
# Out:
#    0 First Name  Last Name  Gender        Country   Age        Date      Id
# 0  1      Dulce      Abril  Female  United States  32.0  15/10/2017  1562.0
# 1  2       Mara  Hashimoto  Female  Great Britain  25.0  16/08/2016  1582.0
# 2  3     Philip       Gent    Male         France   NaN  21/05/2015     NaN
# 3  4   Kathleen     Hanner  Female  United States  25.0  15/10/2017  3549.0
# 4  5    Nereida    Magwood  Female            NaN  58.0  16/08/2016  2468.0
# 5  6     Gaston      Brumm    Male  United States  24.0  21/05/2015  2554.0
# 6  7       Etta       Hurn  Female  Great Britain  56.0  15/10/2017  3598.0
# 7  8    Earlean     Melgar  Female  United States  27.0  16/08/2016  2456.0
# 8  9   Vincenza    Weiland  Female  United States  40.0  21/05/2015  6548.0
# 9  2       Mara  Hashimoto  Female  Great Britain  25.0  16/08/2016  1582.0
# ------------------------------------
#    0 First Name  Last Name  Gender        Country   Age        Date      Id
# ...
